# %% [markdown]
# # Liebherr / Prionoth Data Demo
#
# In dieser Demo habe ich mich mit dem Laden von JSON-Event-Logs beschäftigt. Dieses Verfahren ist die basis für das gemeinsame Projekt mit Liebherr/Prinoth. Wir planen eine Analyse von einschlägigen Maschinen-Logs zur Untersuchung von Mustern innerhalb dieser Daten. Die Daten werden von Pistengerägen (Prinoth) und diversen Maschinen (Liebherr) bereitgestellt. Inhalt des Projekts ist zum einen das Finden einer passenden Datenstruktur die für beide Unternehmen passen kann und andererseits einer Lade/Verarbeitungs/Analysetechnik.

# %%
from pandas import read_json

# %%
data = read_json("../data/liebherr_prinoth_demo.json")
# Out:
#    machine_id                ts_utc event_id         group     code severity  \
# 0    LH-A-042  2026-05-14T07:15:02Z    e0001    Powertrain  PT_1001     info
# 1    LH-A-042  2026-05-14T07:15:06Z    e0002    Powertrain  PT_1100     info
# 2    LH-A-042  2026-05-14T07:15:08Z    e0003    Powertrain  PT_1101     info
# 3    LH-A-042  2026-05-14T07:17:19Z    e0004     Hydraulic  HY_2003  warning
# 4    LH-A-042  2026-05-14T07:17:45Z    e0005     Hydraulic  HY_2004  warning
# 5    LH-A-042  2026-05-14T07:18:03Z    e0006        Sensor  SN_3102    error
# 6    LH-A-042  2026-05-14T07:18:05Z    e0007     Hydraulic  HY_2100    error
# 7    LH-A-042  2026-05-14T07:18:18Z    e0008  Connectivity  CN_4001  warning
# 8    LH-A-042  2026-05-14T07:19:01Z    e0009    Powertrain  PT_1205     info
# 9    LH-A-042  2026-05-14T07:20:12Z    e0010     Hydraulic  HY_2003     info
# 10   LH-A-042  2026-05-14T07:21:40Z    e0011        Sensor  SN_3102     info
# 11   LH-A-042  2026-05-14T07:45:10Z    e0012    Powertrain  PT_1002     info
#
#     priority                                      text   value          unit  \
# 0          4                               Ignition ON     NaN           NaN
# 1          4                    Engine start requested     NaN           NaN
# 2          4                            Engine running     NaN           NaN
# 3          3            Hydraulic oil temperature high   92.40             C
# 4          3   Hydraulic pressure oscillation detected   18.20        bar_pp
# 5          2            Temperature sensor implausible     NaN           NaN
# 6          2                   Hydraulic derate active    0.70  limit_factor
# 7          3        Telematics buffer nearing capacity    0.88         ratio
# 8          4                     Idle speed stabilized  790.00           rpm
# 9          4  Hydraulic oil temperature back to normal   78.60             C
# 10         4        Temperature sensor plausible again     NaN           NaN
# 11         4                              Ignition OFF     NaN           NaN
#
#      source
# 0       ECU
# 1       ECU
# 2       ECU
# 3       ECU
# 4       ECU
# 5       ECU
# 6       ECU
# 7   Gateway
# 8       ECU
# 9       ECU
# 10      ECU
# 11      ECU
