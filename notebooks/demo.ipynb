# %% [markdown]
# # Test in Notion
#
# Das ist eine Demo-Beschreibung, die mein `python` Script automatisch fetchen soll.
#
# Letzte Zeile.

# %%
print("test")
# Out:
# test

# %% [markdown]
# Zweite Markdown Zelle.
