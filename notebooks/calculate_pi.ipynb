# %%
from random import random


N = 1000

# %%
drops = []
for iteration in range(N):
    drop = random(), random()
    drops.append(drop)

# %%
drops
# Out:
# [(0.11159873350583116, 0.16763346209424057),
#  (0.07948880651047763, 0.4116547848726094),
#  (0.5148433723462412, 0.742234993915095),
#  (0.5018312691599598, 0.26090089656023685),
#  (0.02827263302050831, 0.5657266650745033),
#  (0.36851791818828117, 0.5452787780002337),
#  (0.9895659945200423, 0.5552739393500885),
#  (0.2977448143227118, 0.007344970791265171),
#  (0.10435641599649437, 0.754219764552136),
#  (0.875445835590746, 0.5010401742841302),
#  (0.28928575315392435, 0.36100405571798644),
#  (0.8421463743277382, 0.7630967047910203),
#  (0.3936783161843095, 0.6467196224947048),
#  (0.7003280433381628, 0.9986171456223754),
#  (0.5389657847776655, 0.14180350084346827),
#  (0.2542146866544398, 0.9880664630412928),
#  (0.6664660566012526, 0.8276767556296191),
#  (0.6460468064699152, 0.5919339291352593),
#  (0.16852100743619447, 0.7303580997266422),
#  (0.8444886743462507, 0.2847746577776784),
#  (0.6866035092722786, 0.4909297234873905),
#  (0.733446965911197, 0.5595000848605327),
# ...
