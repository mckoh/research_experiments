# %%
from random import random


N = 1000

# %%
drops = []
for iteration in range(N):
    x, y = random(), random()
    r = (x ** 2 + y ** 2) ** 0.5
    drops.append(r)

# %%
drops
# Out:
# [0.9255091182067786,
#  0.7804330677967456,
#  0.6393115666770507,
#  0.7908059943260454,
#  1.08510862146342,
#  0.522174912695336,
#  0.6989261266836942,
#  1.1246079942430987,
#  0.7619927618138146,
#  0.8511261118378519,
#  0.5790499022363803,
#  0.6407746944066507,
#  0.8096319957731746,
#  1.0181162079220776,
#  0.9073780952122572,
#  0.9034372448390244,
#  1.053925631698259,
#  0.43664142779910076,
#  1.0324301464837304,
#  0.054980461051240166,
#  1.021108329058434,
#  0.7554204982484762,
#  0.9353945059856044,
#  0.3978323717960996,
#  1.3577982472246815,
#  0.4914359809548746,
#  0.6539822512188955,
#  0.24087091726566714,
#  0.4772931028975458,
#  0.9819622376169772,
#  1.1348059977564409,
#  0.3923422158388428,
#  0.7904245504735087,
#  1.0644085717607297,
#  0.8665827890006353,
#  1.356823147956077,
#  1.1262787800278333,
#  0.6914898785741117,
#  1.1765688484408003,
#  0.6297252595293347,
#  0.9857468403739936,
#  1.077864520229986,
#  1.1495838351998657,
# ...
